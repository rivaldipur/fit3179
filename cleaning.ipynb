# %%
import pandas as pd

df = pd.read_csv("world_data_2023.csv")

# %%
df.loc[df['Country'] == 'Afghanistan']
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)
# 0  Afghanistan               60           AF                 58.10  \
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code
# 0         652230            323000       32.49          93.0  \
#
#   Capital/Major City Co2-Emissions in tons  ...
# 0              Kabul                  8672  ...  \
#
#   Out of pocket health expenditure Physicians per thousand Population
# 0                           78.40%                    0.28   38041754  \
#
#    Population: Labor force participation (%) Tax revenue (%) Total tax rate
# 0                                     48.90%           9.30%         71.40%  \
#
#   Unemployment rate Urban_population  Latitude  Longitude
# 0             11.12          9797273  33.93911  67.709953
#
# [1 rows x 35 columns]

# %%
df['Co2-Emissions in tons'] = df['Co2-Emissions in tons'].str.replace(',', '')

# %%
df.drop(['Gross tertiary education enrollment (%)'], axis=1, inplace=True)

# %%
df.rename(columns={'Forested_Area_(%)': 'Forested_Area_(%)'}, inplace=True)

# %%
df.head()
# Out:
#        Country Density_(P/Km2) Abbreviation  Agricultural_Land(%)
# 0  Afghanistan              60           AF                  58.1  \
# 1      Albania             105           AL                  43.1
# 2      Algeria              18           DZ                  17.4
# 3      Andorra             164           AD                  40.0
# 4       Angola              26           AO                  47.5
#
#    Land_Area(Km2)  Armed_Forces_size  Birth_Rate  Fertility_Rate
# 0        652230.0           323000.0       32.49            4.47  \
# 1         28748.0             9000.0       11.78            1.62
# 2       2381741.0           317000.0       24.28            3.02
# 3           468.0                NaN        7.20            1.27
# 4       1246700.0           117000.0       40.73            5.52
#
#    Forested Area (%)    GDP_in_USD  ...  Official_language
# 0                2.1  1.910135e+10  ...             Pashto  \
# ...

# %%
df.to_csv('C:\\Users\\rival\\OneDrive\\Desktop\\FIT3179\\fit3179\\world_data_2023.csv', index=False)

# %%
df['Country'] = df['Country'].replace('Central African Republic', 'Central African Rep.')

# %%
df[df['Country'] == "S�����������"]
# Out:
#           Country Density_(P/Km2) Abbreviation  Agricultural_Land(%)
# 150  S�����������             228           ST                  50.7  \
#
#      Land_Area(Km2)  Armed_Forces_size  Birth_Rate  Fertility_Rate
# 150           964.0             1000.0       31.54            4.32  \
#
#      Forested Area (%)   GDP in USD  Infant mortality  Life expectancy
# 150               55.8  429016605.0              24.4             70.2  \
#
#      Maternal mortality ratio Official language  Physicians per thousand
# 150                     130.0               NaN                     0.05  \
#
#      Population  Unemployment rate  Urban_population  Latitude  Longitude
# 150    215056.0              13.37          158277.0       NaN        NaN

# %%
print(df['Official_language'].nunique())
# Out:
# 77
